# %%
# !git clone https://github.com/13952522076/Open-Set-Recognition.git
# Out:
# Cloning into 'Open-Set-Recognition'...
# remote: Enumerating objects: 6030, done.
# remote: Counting objects: 100% (239/239), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 6030 (delta 166), reused 145 (delta 79), pack-reused 5791
# Receiving objects: 100% (6030/6030), 44.97 MiB | 11.38 MiB/s, done.
# Resolving deltas: 100% (4243/4243), done.

# %%
# !pip install libmr
# Out:
# ...
#   Created wheel for libmr: filename=libmr-0.1.9-cp37-cp37m-linux_x86_64.whl size=386630 sha256=83105c2f08e0bf06d7719f07051de95cebad68008d6a5d38f10827dfec085772
#   Stored in directory: /root/.cache/pip/wheels/b0/54/28/fadd1fd7df1f0db683e5d8e05fb06bfa65e329245ad933b534
# Successfully built libmr
# ...

# %%
# %cd Open-Set-Recognition/OSR/OpenMax/
# !python cifar100.py
# Out:
# /content/Open-Set-Recognition/OSR/OpenMax
# cuda
# ==> Preparing data..
# ...
# 169001984it [00:06, 27050781.99it/s]
# Extracting ../../data/cifar-100-python.tar.gz to ../../data
# 	Training data includes 50 classes, 25000 samples.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 	Testing data includes 51 classes (Original 100 classes), 10000 samples.
# 	During testing, openness is 0.5.
# ==> Building model..
#
# Epoch: 1   Learning rate: 0.100000
# ...
